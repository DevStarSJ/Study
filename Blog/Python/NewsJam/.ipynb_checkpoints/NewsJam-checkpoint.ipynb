# %%
import news_rss

# %%
import feedparser
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-83ad40c5a32f> in <module>()
# ----> 1 import feedparser
#
# ImportError: No module named 'feedparser'
