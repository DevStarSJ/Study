# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn

# %%
X = [1,2,3]
Y = [1,2,3]

# %%
W = tf.placeholder(tf.float32)
hypothesis = W * X

cost = tf.reduce_mean(tf.square(hypothesis - Y))
sess = tf.Session()
sess.run(tf.global_variables_initializer())

W_val = []
cost_val = []

for i in range(-30, 50):
    feed_W = i * 0.1
    curr_cost, curr_W = sess.run([cost, W], feed_dict={W: feed_W})
    cost_val.append(curr_cost)
    W_val.append(curr_W)
    
plt.plot(W_val, cost_val)
plt.show()

# %% [markdown]
# ## Gradient descent

# %%
x_data = [1,2,3]
y_data = [1,2,3]

W = tf.Variable(tf.random_normal([1]), name='weight')
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

hypothesis = W * X

cost = tf.reduce_sum(tf.square(hypothesis - Y))

learning_rate = 0.1
gradient = tf.reduce_mean((W * X - Y) * X)
decent = W - learning_rate * gradient
update = W.assign(decent)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

c_val = []
w_val = []
s_val = []

for step in range(21):
    u = sess.run(update, feed_dict= {X: x_data, Y:y_data})
    c = sess.run(cost, feed_dict={X: x_data, Y: y_data});
    w = sess.run(W)
    print(step, c, w)
    c_val.append(c)
    w_val.append(w)
    s_val.append(step)
    
    
plt.plot(s_val, c_val)
plt.show()

plt.plot(s_val, w_val)
plt.show()
# Out:
# 0 8.49514 [ 0.22102895]
# 1 2.4164 [ 0.58454883]
# 2 0.68733 [ 0.77842605]
# 3 0.195507 [ 0.88182724]
# 4 0.0556109 [ 0.93697453]
# 5 0.0158182 [ 0.96638644]
# 6 0.0044994 [ 0.98207277]
# 7 0.00127983 [ 0.99043882]
# 8 0.00036404 [ 0.9949007]
# 9 0.00010355 [ 0.99728036]
# 10 2.94539e-05 [ 0.99854952]
# 11 8.37831e-06 [ 0.99922639]
# 12 2.38345e-06 [ 0.99958742]
# 13 6.77972e-07 [ 0.99977994]
# 14 1.92874e-07 [ 0.99988264]
# 15 5.48809e-08 [ 0.99993742]
# 16 1.55978e-08 [ 0.99996662]
# 17 4.44026e-09 [ 0.99998218]
# 18 1.27329e-09 [ 0.99999046]
# 19 3.61172e-10 [ 0.99999493]
# 20 1.01682e-10 [ 0.99999732]

# %%
X = [1,2,3]
Y = [1,2,3]

W = tf.Variable(5.0)

hypothesis = W * X

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

w_val = []
s_val = []

for step in range(21):
    w = sess.run(W)
    sess.run(train)
    print(step, w)
    w_val.append(w)
    s_val.append(step)

plt.plot(s_val, w_val)
plt.ylim(0,5)
plt.show()
# Out:
# 0 5.0
# 1 1.26667
# 2 1.01778
# 3 1.00119
# 4 1.00008
# 5 1.00001
# 6 1.0
# 7 1.0
# 8 1.0
# 9 1.0
# 10 1.0
# 11 1.0
# 12 1.0
# 13 1.0
# 14 1.0
# 15 1.0
# 16 1.0
# 17 1.0
# 18 1.0
# 19 1.0
# 20 1.0

# %%
X = [1,2,3]
Y = [1,2,3]

W = tf.Variable(-5.0)

hypothesis = W * X

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

w_val = []
s_val = []

for step in range(21):
    w = sess.run(W)
    sess.run(train)
    print(step, w)
    w_val.append(w)
    s_val.append(step)

plt.plot(s_val, w_val)
plt.ylim(-5,2)
plt.show()
# Out:
# 0 -5.0
# 1 0.6
# 2 0.973333
# 3 0.998222
# 4 0.999882
# 5 0.999992
# 6 0.999999
# 7 1.0
# 8 1.0
# 9 1.0
# 10 1.0
# 11 1.0
# 12 1.0
# 13 1.0
# 14 1.0
# 15 1.0
# 16 1.0
# 17 1.0
# 18 1.0
# 19 1.0
# 20 1.0
