# %% [markdown]
# ## 간단한 예제
#
# - `tensorflow`가 정상적으로 설치되었는지 확인

# %%
import tensorflow as tf

# %%
a = tf.placeholder("float")
b = tf.placeholder("float")

y = tf.mul(a, b)

sess = tf.Session()
sess.run(y, feed_dict={a:3, b:3})
# Out:
# 9.0

# %% [markdown]
# ## 선형회귀분석 (Linear Regression)
#
# - `독립변수(xi)`, `상수항(b)`, `종속변수(y)` 사이의 관계를 모델링 하는 방법

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $y = 0.1 * x + 0.3$ 의 데이터에 약간의 랜덤값을 줘서 데이터 생성

# %%
num_points = 1000
vectors_set = []

for i in range(num_points):
    xi = np.random.normal(0.0, 0.55)
    yi = xi * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([xi, yi])
    
x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

# %%
plt.plot(x_data, y_data, 'ro')
plt.legend()
plt.show()
# Out:
# /Users/seokjoonyun/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# #### 위 데이터를 이용해서 학습
#
# - `y_data` = `W` * `x_data` + `b` 의 모델로 표현
# - 데이터 셋들을 반복 적용하여 더 정확한 결과를 위한 `W`,`b`를 수정
# - `비용함수(cost function)`
#   - 반복이 일어날 때마다 개선되고 있는지 확인하기 위해 얼마나 좋은 직선인지 측정
#   - `오차함수 (error function)`이라고도 함
# - `평균제곱오차 (mean square error)`를 비용함수로 사용
#   - 실제 값과 알고리즘이 반복할때마다 추정한 값 사이의 거리를 오차로 하는 값의 평균

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

# %%
loss = tf.reduce_mean(tf.square(y - y_data))

# %%
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %%
init = tf.initialize_all_variables()
sess = tf.Session()
sess.run(init)

# %%
for step in range(8):
    sess.run(train)
    print('train step [{0}] : {1} , {2}, {3}'.format(step, sess.run(W), sess.run(b), sess.run(loss)))

print(sess.run(W), sess.run(b))
# Out:
# train step [0] : [ 0.16950765] , [ 0.30305594], 0.002532218350097537
# train step [1] : [ 0.14735836] , [ 0.30297434], 0.0017071913462132215
# train step [2] : [ 0.13225971] , [ 0.30292058], 0.0013238160172477365
# train step [3] : [ 0.12196733] , [ 0.30288395], 0.0011456679785624146
# train step [4] : [ 0.11495126] , [ 0.30285898], 0.0010628876043483615
# train step [5] : [ 0.11016858] , [ 0.30284196], 0.0010244193254038692
# train step [6] : [ 0.10690834] , [ 0.30283037], 0.0010065450333058834
# train step [7] : [ 0.10468592] , [ 0.30282244], 0.0009982383344322443
# [ 0.10468592] [ 0.30282244]

# %%
plt.plot(x_data, y_data, 'ro')
plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# /Users/seokjoonyun/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
