# %%
# %bylab
# %matplotlib notebook

plot(np.random.randn(100))
# Out:
# ERROR: Line magic function `%bylab` not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b547c55c2ba9> in <module>()
#       2 get_ipython().magic('matplotlib notebook')
#       3
# ----> 4 plot(np.random.randn(100))
#
# NameError: name 'plot' is not defined
